# %%
# author: Jing
# date: May 24 2019
# function: survival analysis based on cox model, plot results with seaborn

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sksurv.datasets import load_veterans_lung_cancer
from sksurv.column import encode_categorical
from sksurv.metrics import concordance_index_censored
from sksurv.linear_model import CoxPHSurvivalAnalysis

from sksurv.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt
from sksurv.nonparametric import kaplan_meier_estimator
sns.set_style("whitegrid")
# generate the response variable for cox model
from sksurv.util import Surv
from sksurv.linear_model import CoxnetSurvivalAnalysis

# %%
filename = "gene_mutations_clinical_mskcc.txt"
data_ = pd.read_csv(filename, sep = '\t')#, dtype = 'object')

d = {'LIVING': False, 'DECEASED': True}
data_["OS_STATUS"] = data_["OS_STATUS"].map(d)

data_y = data_[['OS_STATUS','OS_MONTHS']]

data_x = data_
data_x = data_x.drop(columns = ['Tumor_Sample_Barcode','PATIENT_ID','OS_MONTHS','OS_STATUS','ONCOTREE_CODE'])

#a = OneHotEncoder().fit_transform(data_x["SEX"])
x = encode_categorical(data_x)
y = Surv.from_dataframe(event='OS_STATUS', time='OS_MONTHS', data=data_)

# %%
data_x.columns
# Out:
# Index(['ABL1', 'ACVR1', 'AGO2', 'AKT1', 'AKT2', 'AKT3', 'ALK', 'ALOX12B',
#        'AMER1', 'ANKRD11',
#        ...
#        'YAP1', 'YES1', 'ZFHX3', 'ZRSR2', 'TMB_SCORE', 'SEX', 'AGE_GROUP',
#        'DRUG_TYPE', 'SAMPLE_TYPE', 'CANCER_TYPE'],
#       dtype='object', length=480)

# %%
estimator = CoxPHSurvivalAnalysis()
estimator.fit(x, y)

pd.Series(estimator.coef_, index=x.columns)

sns.set(rc={'figure.figsize':(11.7,85)})

ax = sns.barplot(y = x.columns, x = estimator.coef_)
plt.savefig('./out/mskcc/cox_overall_linear.pdf')

ind = np.argsort(abs(estimator.coef_))
ind = ind[::-1] #reverse the order
sns.set(rc={'figure.figsize':(15.7,105)})

ax = sns.barplot(y = x.columns[ind], x = estimator.coef_[ind])
plt.savefig('./out/mskcc/cox_overall_linear_ordered.pdf')
# ref: the human protein atlas https://www.proteinatlas.org/ENSG00000105173-CCNE1/pathology
# GTF21 renal; HIST1H3H renal pancreatic(stomach) cervical; CCNE1 liver endometrial ovarian; knstrn renal pancreatic
# rragc liver; lyn liver; RRAS renal glioma lung; rac2 renal, breast;nthl1 colorectal breast prostate lung liver

# %%
mu, sigma = 0, 0.05
noise = np.random.normal(mu, sigma, 10)
noise
# Out:
# array([ 0.04992939,  0.02739048, -0.0266924 ,  0.05609164,  0.00434309,
#         0.02469141, -0.07807713,  0.07188866,  0.05962584, -0.01303685])

# %%
# within cancer type COXPHSurvival; original matrix is singular
mu, sigma = 0, 0.001
noise = np.random.normal(mu, sigma, (x.shape))
f = open("./out/mskcc/mskcc_gene_coxphsurvival.txt","w+")
tpx = x+noise
for cancer_type in ('Breast Cancer', 'Esophagogastric Cancer', 'Bladder Cancer',
       'Non-Small Cell Lung Cancer', 'Glioma', 'Head and Neck Cancer',
       'Melanoma', 'Colorectal Cancer', 'Renal Cell Carcinoma',
       'Cancer of Unknown Primary'):#data_x["CANCER_TYPE"].unique():
    mask = data_["CANCER_TYPE"] == cancer_type
    ind = np.where(mask)[0].tolist()
    tmpt = tpx.loc[mask]
    tmpy = y[ind]
    noise = np.random.normal(mu, sigma, (tmpt.shape))
    tmpx  = tmpt + 2*noise
    
    #print(tmpx.shape, tmpy.shape)
    net = CoxPHSurvivalAnalysis() # L1
    net.fit(tmpx, tmpy)
    order = np.argsort((net.coef_))
    order = order[::-1][0:50]
    f.write(cancer_type + "\r" + str(np.count_nonzero(tmpt))+"\r" + str(x.columns[order].values)+'\n')
    
    sns.set(rc={'figure.figsize':(15.7,20)})

    ax = sns.barplot(y = x.columns[order], x = net.coef_[order])
    plt.savefig('./out/mskcc/Cox/cox_' + cancer_type + '_addnoise2.pdf')
# Out:
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=3.06193e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=1.18824e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=5.94415e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=2.01227e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=6.49139e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=2.43107e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=1.87052e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=3.35933e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=2.91289e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=3.15503e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=3.6701e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=4.97256e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=2.00535e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=1.06095e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=1.10996e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=4.44951e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=2.48909e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=4.34655e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=2.05857e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=3.7235e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=1.03797e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=6.55201e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=1.81859e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=1.75412e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=5.04921e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=2.21317e-27): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=1.34074e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=1.09999e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=3.66229e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=1.06762e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=6.52534e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=7.29302e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=4.5404e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=9.05271e-27): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=2.64361e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=3.41707e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=9.05217e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=3.6617e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=2.29162e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=6.435e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=1.45153e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=8.94831e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=1.08129e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=9.42588e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=1.12857e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=5.96267e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=7.95059e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=4.46561e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=6.48759e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=1.65622e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=3.1017e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=8.12242e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=3.35745e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=2.05878e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=5.06318e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=5.2793e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=2.41643e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=1.58178e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=1.87756e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=3.69957e-26): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=1.93104e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=1.29794e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=1.28321e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=1.00578e-25): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:330: LinAlgWarning: Ill-conditioned matrix (rcond=4.79215e-28): result may not be accurate.
#   overwrite_a=False, overwrite_b=False, check_finite=False)
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:165: RuntimeWarning: divide by zero encountered in log
#   loss -= (xw[i] - numpy.log(risk_set)) / n_samples
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:202: RuntimeWarning: invalid value encountered in true_divide
#   gradient -= (x[i:i + 1] - risk_set_x / risk_set) * inv_n_samples
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:204: RuntimeWarning: invalid value encountered in true_divide
#   a = risk_set_xx / risk_set
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py:205: RuntimeWarning: invalid value encountered in true_divide
#   z = risk_set_x / risk_set
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-414-857f997f20b3> in <module>
#      16     #print(tmpx.shape, tmpy.shape)
#      17     net = CoxPHSurvivalAnalysis() # L1
# ---> 18     net.fit(tmpx, tmpy)
#      19     order = np.argsort((net.coef_))
#      20     order = order[::-1][0:50]
#
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py in fit(self, X, y)
#     331
#     332             if not numpy.all(numpy.isfinite(delta)):
# --> 333                 raise ValueError("search direction contains NaN or infinite values")
#     334
#     335             w_new = w - delta
#
# ValueError: search direction contains NaN or infinite values

# %%
# within cancer COXNET without TMB_SCORE
new_x = x.drop(columns = "TMB_SCORE")
for cancer_type in ('Breast Cancer', 'Esophagogastric Cancer', 'Bladder Cancer',
       'Non-Small Cell Lung Cancer', 'Glioma', 'Head and Neck Cancer',
       'Melanoma', 'Colorectal Cancer', 'Renal Cell Carcinoma',
       'Cancer of Unknown Primary'):#data_x["CANCER_TYPE"].unique():
    mask = data_["CANCER_TYPE"] == cancer_type
    ind= np.where(mask)[0].tolist()
    tmpx = new_x.loc[mask]
    tmpy = y[ind]

    #print(tmpx.shape, tmpy.shape)

    coxnet = CoxnetSurvivalAnalysis()#l1_ratio = 0.000001) # L1
    coxnet.fit(tmpx, tmpy)
    coef = coxnet.coef_[np.argmax(abs(coxnet.coef_),axis=1)]#pd.DataFrame(, index = new_x.columns, dtype=float)
    #print(coxnet.coef_.shape)
    print(np.nonzero(coef))
    #print(coxnet.coef_[474,0],coxnet.coef_[474,1],coxnet.coef_[474,2],coxnet.coef_[474,3],coxnet.coef_[4,0])
    order = np.argsort((abs(coef)))
    order = order[::-1]
    #print(caner_type, x.columns[474])
    #sns.set(rc={'figure.figsize':(15.7,15)})
    sns.set_context("paper", font_scale=9)   
    sns.set(rc={'figure.figsize':(15.7,105)})
    ax = sns.barplot(y = new_x.columns[order], x = coef[order])
    plt.savefig('./out/mskcc/Cox/coxnet_' + cancer_type + '.pdf')
# Out:
# (array([], dtype=int64), array([], dtype=int64))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/seaborn/utils.py in categorical_order(values, order)
#     525             try:
# --> 526                 order = values.cat.categories
#     527             except (TypeError, AttributeError):
#
# AttributeError: 'Index' object has no attribute 'cat'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-437-ad168174b2eb> in <module>
#      24     sns.set_context("paper", font_scale=9)
#      25     sns.set(rc={'figure.figsize':(15.7,105)})
# ---> 26     ax = sns.barplot(y = new_x.columns[order], x = coef[order])
#      27     plt.savefig('./out/mskcc/Cox/coxnet_' + cancer_type + '.pdf')
#
# /usr/local/lib/python3.7/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# /usr/local/lib/python3.7/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
#    1606         self.establish_variables(x, y, hue, data, orient,
# -> 1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#
# /usr/local/lib/python3.7/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     201
#     202                 # Get the order on the categorical axis
# --> 203                 group_names = categorical_order(groups, order)
#     204
#     205                 # Group the numeric data
#
# /usr/local/lib/python3.7/site-packages/seaborn/utils.py in categorical_order(values, order)
#     527             except (TypeError, AttributeError):
#     528                 try:
# --> 529                     order = values.unique()
#     530                 except AttributeError:
#     531                     order = pd.unique(values)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in unique(self, level)
#    2000         if level is not None:
#    2001             self._validate_index_level(level)
# -> 2002         result = super(Index, self).unique()
#    2003         return self._shallow_copy(result)
#    2004
#
# /usr/local/lib/python3.7/site-packages/pandas/core/base.py in unique(self)
#    1312         else:
#    1313             from pandas.core.algorithms import unique1d
# -> 1314             result = unique1d(values)
#    1315
#    1316         return result
#
# /usr/local/lib/python3.7/site-packages/pandas/core/algorithms.py in unique(values)
#     360
#     361     table = htable(len(values))
# --> 362     uniques = table.unique(values)
#     363     uniques = _reconstruct_data(uniques, dtype, original)
#     364     return uniques
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.StringHashTable.unique()
#
# ValueError: Buffer has wrong number of dimensions (expected 1, got 2)

# %%
# within cancer COXNET with TMB_SCORE
for cancer_type in ('Breast Cancer', 'Esophagogastric Cancer', 'Bladder Cancer',
       'Non-Small Cell Lung Cancer', 'Glioma', 'Head and Neck Cancer',
       'Melanoma', 'Colorectal Cancer', 'Renal Cell Carcinoma',
       'Cancer of Unknown Primary'):#data_x["CANCER_TYPE"].unique():
    mask = data_["CANCER_TYPE"] == cancer_type
    ind= np.where(mask)[0].tolist()
    tmpx = x.loc[mask]
    tmpy = y[ind]

    #print(tmpx.shape, tmpy.shape)

    coxnet = CoxnetSurvivalAnalysis(l1_ratio = 0.9) # L1
    coxnet.fit(tmpx, tmpy)
    coef = np.max(abs(coxnet.coef_),axis=1)#pd.DataFrame(, index = new_x.columns, dtype=float)
    #print(coxnet.coef_.shape)
    print(np.nonzero(coef))
    #print(coxnet.coef_[474,0],coxnet.coef_[474,1],coxnet.coef_[474,2],coxnet.coef_[474,3],coxnet.coef_[4,0])
    order = np.argsort(coef)
    order = order[::-1][0:20]
    #print(caner_type, x.columns[474])
    sns.set(rc={'figure.figsize':(15.7,15)})
    sns.set_context("paper", font_scale=5)   
    ax = sns.barplot(y = x.columns[order], x = coef[order])
    plt.savefig('./out/mskcc/Cox/coxnetTMB_' + cancer_type + '.pdf')
# Out:
# (array([474]),)
# (array([474]),)
# (array([474]),)
# (array([474]),)
# (array([474]),)
# (array([474]),)
# (array([474]),)
# (array([474]),)
# (array([474]),)
# (array([474]),)

# %%
#Measuring the Performance of Survival Models C-index
prediction = estimator.predict(x)
# data_y = data_[['OS_STATUS','OS_MONTHS']]

result = concordance_index_censored(data_y["OS_STATUS"], data_y["OS_MONTHS"], prediction)
result[0]
# Out:
# 0.7982352401439539

# %%
x['TMB_SCORE']#["TMB_SOCRE"]#'Tumor_Sample_Barcode'
# Out:
# 0        5.580000
# 1        6.691462
# 2       16.728656
# 3       11.152437
# 4        1.120000
# 5       13.382924
# 6        6.691462
# 7        3.345731
# 8        5.580000
# 9        8.921950
# 10       5.580000
# 11       2.230000
# 12      16.728656
# 13       5.580000
# 14       8.920000
# 15       2.230000
# 16       1.115244
# 17       6.691462
# 18       1.120000
# 19      13.380000
# 20       3.345731
# 21       3.350000
# 22       6.690000
# 23      22.304874
# 24       5.576219
# 25       3.350000
# 26       2.230487
# 27       1.120000
# 28      26.765849
# 29       6.690000
#           ...
# 1580    59.684619
# 1581     3.510860
# 1582    14.043440
# 1583     4.388575
# 1584     0.877715
# 1585     4.388575
# 1586    13.165725
# 1587     5.266290
# 1588    12.288010
# 1589     7.021720
# 1590     4.388575
# 1591    41.252605
# 1592     8.777150
# 1593     6.144005
# 1594     5.266290
# 1595     8.777150
# 1596     4.388575
# 1597    15.798870
# 1598     4.388575
# 1599     2.633145
# 1600     3.510860
# 1601     2.633145
# 1602     4.388575
# 1603    60.562334
# 1604     7.899435
# 1605     6.144005
# 1606    27.209165
# 1607     2.633145
# 1608     6.144005
# 1609     6.144005
# Name: TMB_SCORE, Length: 1610, dtype: float64

# %%
prediction = estimator.predict(x['TMB_SCORE'])
# data_y = data_[['OS_STATUS','OS_MONTHS']]

result = concordance_index_censored(data_y["OS_STATUS"], data_y["OS_MONTHS"], prediction)
result[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-211-0bc4bb3d84d5> in <module>
# ----> 1 prediction = estimator.predict(x['TMB_SCORE'])
#       2 # data_y = data_[['OS_STATUS','OS_MONTHS']]
#       3
#       4 result = concordance_index_censored(data_y["OS_STATUS"], data_y["OS_MONTHS"], prediction)
#       5 result[0]
#
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py in predict(self, X)
#     376         X = numpy.atleast_2d(X)
#     377
# --> 378         return numpy.dot(X, self.coef_)
#     379
#     380     def predict_cumulative_hazard_function(self, X):
#
# ValueError: shapes (1,1610) and (493,) not aligned: 1610 (dim 1) != 493 (dim 0)

# %%
# Feature Selection: Which Variable is Most Predictive

def fit_and_score_features(X, y):
    n_features = X.shape[1]
    scores = np.empty(n_features)
    m = CoxPHSurvivalAnalysis()
    for j in range(n_features):
        Xj = X[:, j:j+1]
        m.fit(Xj, y)
        scores[j] = m.score(Xj, y)
    return scores

scores = fit_and_score_features(x.values, y)
pd.Series(scores, index=x.columns).sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-166-5580ea25d378> in <module>
# ----> 1 estimator.predict_cumulative_hazard_function(x)
#
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py in predict_cumulative_hazard_function(self, X)
#     401             Predicted cumulative hazard functions.
#     402         """
# --> 403         return self._baseline_model.get_cumulative_hazard_function(self.predict(X))
#     404
#     405     def predict_survival_function(self, X):
#
# /usr/local/lib/python3.7/site-packages/scikit_survival-0.9.dev5+g9fdc0f7-py3.7-macosx-10.14-x86_64.egg/sksurv/linear_model/coxph.py in predict(self, X)
#     376         X = numpy.atleast_2d(X)
#     377
# --> 378         return numpy.dot(X, self.coef_)
#     379
#     380     def predict_cumulative_hazard_function(self, X):
#
# ValueError: shapes (1610,493) and (483,) not aligned: 493 (dim 1) != 483 (dim 0)
